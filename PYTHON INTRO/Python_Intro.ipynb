# %%
# First code 

print("my name is muskan")
# Out:
# my name is muskan

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print ("hello")
# Out:
# hello

# %%
 
print(len(keyword.kwlist))
# Out:
# 35

# %%
num1 = 10
print("The number is:",num1,"The type is :",type(num1))
# Out:
# The number is: 10 The type is : <class 'int'>

# %%
num2 = 0.3 
print("the number is",num2,"The type of num is :",type(num2))
# Out:
# the number is 0.3 The type of num is : <class 'float'>

# %%
# single line string 
str = "welcome"
print(str)

# multi-line string 
str2 = "Python \n String"
print(str2)
# Out:
# welcome
# Python
#  String

# %%
# string repetition
str = "helloo"
print(str * 2)
print(str * 5)
# Out:
# helloohelloo
# helloohelloohelloohelloohelloo

# %%
# addition or concatenation operator 
str1 = "Hello"
str2 = "World"
str3 = " "
print(str1+ str3 + str2)
# Out:
# Hello World

# %%
# length of string?
str7="hello+my_name_is_muskan"
str2 = "hello"
print(len(str2))
print(len(str7))
# Out:
# 5
# 23

# %%
str1 = 'hello dear friends, welcome to python classes'
print('friends' in str1)
# Out:
# True

# %%
print('my' in str1)
# Out:
# False

# %%
# to convert all in uppercase
print(str1.upper())
print(str1.lower())
# Out:
# HELLO DEAR FRIENDS, WELCOME TO PYTHON CLASSES
# hello dear friends, welcome to python classes

# %%
# title - is used to convert the first character of each word to uppercase and all remaining characters to lowercase 

# istile  - check wheather a string is titlecased. True if all words in string starts with capital letter and False otherwise. 

# capitalized - it convert the first letter of string  to uppercase ( hello world -- Hello world)

# swapcase - it converts all uppercase to lowercase and lowercase to uppercase 

# isalpha - check wheather all the characters in a string are alphabetic and not empty. it gives output in T/F

# isalnum - check all characters are alphanumeric ( letter or digits only )( Special symbols are not alphanumeric)

# %%
# comments 

''' this
is 
a 
multiline 
comment
'''

print()

# %%
# Operators 
# +,-,*,/,%,**

x = 5
y = 2

print("The Addition of x and y:",x+y)
print("The Subtraction of x and y:",x-y)
# Out:
# The Addition of x and y: 7
# The Subtraction of x and y: 3
