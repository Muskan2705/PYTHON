# %% [markdown]
# PYTHON
#
# KEYWORDS - keywords are special reserved words that convey special meaning to the compiler
#            each keyword has a special meaning to the specific operation.
#
#            There are 35 keywords -- to print keywords
#            import Keyword
#            print(Keyword,kwlist)
#            print(len(keyword.kwlist)

# %% [markdown]
# VARIABLES
# variable are also known as identifiers which is used to hold some values
#
# it is like a container that hold the value
#
# there are some rules for naming an identifiers
# 1) first character must be an alphabet or underscore(_)
# 2) do not contain any whitespace or special character(!,@,#,$,%,^,&,*)
# 3) no kwywords are used as identifiers
# 4) identifiers are case-sensitive

# %% [markdown]
# DATA TYPES
#      define the type of data is being stored.
#
# There are different types of datatype available in python:
#   1) Int
#   2) Float
#   3) Boolean
#   4) complex number

# %% [markdown]
# Type casting
#
# convert data type into another data type
# string into float or vise-versa
#
# there are two type of casting : 1. implicit   or   2. Explicit

# %% [markdown]
# OPERATORS
#
# 1) Arithmetic Operator :  +,-,*,/,%
# 2) Relational Operator : >,<,==,!=
# 3) Logical Operator : AND, OR, NOT

# %% [markdown]
# TAKING INPUT FROM USER
#
# input() and print() are the standard input and output operation
#
# for input:
#     a = input('Enter your number')
#
# for output:
#     print(a)

# %%
-------STRING ---------------
string : strings are the sequence of character enclosed in single quotes (' ') or double quotes (" ")
 
------------- concatination of string  : (+) join two string together 

 string Repetition : (*) - print(num*2) astrisk operator is used to repeat string multiple times .

 find length of the string : print("the lenght of string :",len(num))

 .
 .
 
 
---------- FORMAT IN STRING AND F STRING ---------------
.

example of .format() 

name = "Muskan"
age = 21
print("My name is {} and I am {} years old.".format(name, age))
.

 example of f string 

name = "Muskan"
age = 21

print(f"My name is {name} and I am {age} years old..

---- Count: count() tells you how many times a character or substring occurs.
      text = "banana"
      print(text.count("a"))

      output:3
      u----nSplit : split() breaks a string into a list.
                 ext = "Python is easy"
                 print(text.split()

                 OUTPUT - ['Python','is','easy']l-----------it
 partiti: partition() divides a string into exactly 3 parts:

before separator
separator
after separator

text = "Python is easy"
print(text.partition("is"))
Output:
('Python ', 'is', ' easy')

---------Sep
wewe use sep function to separates values 
for example :
            print("Python", "Java", "C++", sep="-")
            
            output : Python-Java-C++ ep )

# %%
# and we have to mention both condition , or in list

# %%
n = "apple-mango-banana"
first, separator, last = n.partition('-')

print(last)
# Out:
# mango-banana
