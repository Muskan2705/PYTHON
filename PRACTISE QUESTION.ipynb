# %%
# 9,10,11 ABSENT

# %%
# Q1 input from user and print using f string 
name = input("enter your name ")
print(f'Hello {name},Welcome to python class')
# Out:
# enter your name  muskan
# Hello muskan,Welcome to python class

# %%
# Q2 WAP that take input from users and perfrom addition, sub, mul, div

num1 = float (input('Enter Your Ist Number'))
num2 = float (input('Enter Your 2nd Number'))

Addition = num1 + num2
Subtraction = num1 - num2
Multiplication = num1* num2 
# Division = num1 / num2 

           
print ('The Addition of two no. :',Addition)
print ('The Subtraction of two no. :',Subtraction)
print ('The Multiplication of two no. :',Multiplication)
# print ('The Division of two no. :',Division)

if num2 != 0:
    Division = num1 / num2 
    print('Division:',Division)

else:
    print('Not divisible')
# Out:
# Enter Your Ist Number 5
# Enter Your 2nd Number 0
# The Addition of two no. : 5.0
# The Subtraction of two no. : 5.0
# The Multiplication of two no. : 0.0
# Not divisible

# %%
# Q3 WAP that take input and check it it is +ve or -ve
num =float (input('Enter your Number'))

if num>0:
    print('The no. is positive')

elif num<0:
    print('The no. is Negative')

else:
    print('The no is Zero')
# Out:
# Enter your Number 4
# The no. is positive

# %%
# Q4 WAPinput from user and check if it is even or odd

num = float(input('Enter Your Number'))

if num%2 == 0 :
    print('The number is even')

else:
    print('The no is odd')
# Out:
# Enter Your Number 789
# The no is odd

# %%
# Q5 WAP tahat take a word from user, If lengthh is greater than 5 print(long word) and otherwise print(short word)

word = input('Enter Your Word')
# print(len(word))

if len(word) >5:
    print(f"its length is {len(word)}, and it is a Long Word")
else:
    print(f"Its length is {len(word)}, and it is a Short Word")
# Out:
# Enter Your Word neha
# Its length is 4, and it is a Short Word

# %%
# Q 6 create list and perform indexing 

numbers = [10,20,30,40,50]

print('First Element of list is:',numbers[0])
print('Last Element of list is :' ,numbers[-1])
print('The length of the list is:' ,len(numbers))
# Out:
# First Element of list is: 10
# Last Element of list is : 50
# The length of the list is: 5

# %%
# Q7 same process with tuple 

tup1 = ('Delhi',' Mumbai', ' Bengaluru',' Chandigarh', ' Gurugram')
print('First Element of tuple is:',tup1[0])
print('Last Element of tuple is :' ,tup1[-1])
print('The length of the tuple is:' ,len(tup1))
# Out:
# First Element of tuple is: Delhi
# Last Element of tuple is :  Gurugram
# The length of the tuple is: 5

# %%
# Q8 create a dict and print name and course 
student = {'name':'Ali',"age":20, "course":"Python"}

print(student["name"])
print(student["course"])
# Out:
# Ali
# Python

# %%
# Q9 Set . Create two sets

A = {1,2,3,4}
B ={3,4,5,6}

print('The union of set A and B is:',A|B) #Or we can use A.union(B)
print('The Intersection of A and B is:',A.intersection(B))  # oe we can use A & B
# Out:
# The union of set A and B is: {1, 2, 3, 4, 5, 6}
# The Intersection of A and B is: {3, 4}

# %%
# Q 10 WAP that takes marks as a input from user and print grades 

marks = int(input("Enetr Your Marks"))

if marks >=90:
    print('Grade A')

elif marks >=70:
    print('Grade B')

elif marks >=50:
    print("Grade C")

else:
    print('Fail')
# Out:
# Enetr Your Marks 70
# Grade B

# %%
# Q11 WAP that ttake a sentence from user ande print sentence in lowercase,uppercase and length of sentence

s = input('Enter Your Sentence')

print('The original sentence :', s)
print ('The sentence in lowercase:', s.lower())

print ('The sentence in uppercase:', s.upper())

print('The length of Sentence :', len(s))
# Out:
# Enter Your Sentence mY dhwebfcj
# The original sentence : mY dhwebfcj
# The sentence in lowercase: my dhwebfcj
# The sentence in uppercase: MY DHWEBFCJ
# The length of Sentence : 12

# %%
# Q12 input from user and check startwith or not 

# if start with A then print Start with A otherwise Does not start with A

w = input('Enter Your word').lower()

if w.startswith("a"):
    print('Starts with A')

else:
    print('Does not start with A')
# Out:
# Enter Your word mango
# Does not start with A

# %%
# Q 13 input from user and find large number 

a = int(input("Enter Ist No."))
b = int(input('Enter 2nd No.'))       

if a>b:
    print('Ist no. is greater than 2nd')
elif b>a:
    print('2nd no is greater than 1st')
else:
    print('2nd number is smaller than Ist')
# Out:
# Enter Ist No. 78
# Enter 2nd No. 90
# 2nd no is greater than 1st

# %%
a = int(input("Enter Ist No."))
b = int(input('Enter 2nd No.'))       

if a > b:
    print ('The larger no :',a)

# elif b > a:
#     print('  the larger no :',b)

else:
    print('the larger no :',b)
# Out:
# Enter Ist No. 77
# Enter 2nd No. 90
# the larger no : 90

# %%
# Q 14 WAP that take input fromuser and check if it divisible by 5 or not 


n = float(input('Enter Your Number:'))

if n % 5 == 0:
    print('It is divisible by 5')

else:
    print("Not divisible by 5")
# Out:
# Enter Your Number: 90
# It is divisible by 5

# %%
# Q15 create a list and print highest marks and lowest marks 

list = [45,78,90,66,88]

print('Highest No.',max(list))
print('Lowest No.',min(list))
# Out:
# Highest No. 90
# Lowest No. 45

# %%
# Q16 create a tuple and check if blue is exist in it or not 

colors = ("red","blue","green","yellow")
word = 'blue'
if word in colors:
    print('Color Found')

else:
    print('Color Not Found')
# Out:
# Color Found

# %%
# Q 17 same as Q8

# %%
# Q 18 create two sets and print elements only in A and Element of B only 
A = {10,20,30,40}
B = {30,40,50,60}

print("A = ",A)
print("B = ",B)

print('The elements only in A :', A-B)
print ('The elements only in B :',B-A)
# Out:
# A =  {40, 10, 20, 30}
# B =  {40, 50, 60, 30}
# The elements only in A : {10, 20}
# The elements only in B : {50, 60}

# %%
# Q19 age from user and check it is it !8+ or not

age = int(input("Enter Your AGE"))

if age >= 18:
    print('Eligible to vote')

else:
    print('Not eligible to vote')
# Out:
# Enter Your AGE 13
# Not eligible to vote

# %%
# Q20 password from user and checks if the length is less than 8 pprint weak password otherwise strong password 

p = input("Enter Password")
print('The length of password is:',len(p))

if len(p) <8:
      print('weak password')

else:
      print('strong password')
# Out:
# Enter Password muskaner553
# The length of password is: 11
# strong password
