# %%
def greet(name,greeting="hello"):
    print(greeting,name)

greet("Alice")
greet('Muskan','Hiiiii')
# Out:
# hello Alice
# Hiiiii Muskan

# %%
def area(length,width=1):
    return width*length

print(area(5))
print(area(5,6))
# Out:
# 5
# 30

# %%
# args (Arbitrary positional Arguments)
# Kwargs (Arbitary keywords Arguments)

# %%
# args

def add_numbers(args):
    total = 0
    for num in args:
        total += num 
        print('sum:',total)


# add_numbers(4)
# add_numbers(1,2,3,4)
# add_numbers(1,50)

# %%
def print_info(**kwargs):
    for key,value in kwargs.items():
        print(key + ":",value)

print_info(name="Muskan",age=21, city="Delhi")
# Out:
# name: Muskan
# age: 21
# city: Delhi

# %%
# Python Exception

# %%
# 23 july 26

# %%
# Exception 


# syntax


# try :
         #write code here 
# except : 
        # write code here

# %%
# example

try:
    numerator = 10
    denominator = 0
    result = numerator/denominator 
    print (result)

except:
    print('cannot be divided by zero')
# Out:
# cannot be divided by zero

# %%
try:
    even_number = [2,4,6,8]
    print(even_number[5])

except ZeroDivisionError:
    print('denominator cannot be 0')

except IndexError:
    print('Index is out of Bound')
# Out:
# Index is out of Bound

# %%
try:
    num1 = 10
    num2 = 2
    result = num1/num2
    print(result)

except ZeroDivisionError:
    print('You Cannot divide by Zero')

except ValueError:
    print("That's not a valid number!")

finally:
    print('This is final block')
# Out:
# 5.0
# This is final block

# %%
try:
    age = int(input('Enter your age'))
    print("Your Age is :" ,age)

except ValueError:
    print('Please enter a valid number')
# Out:
# Enter your age mus
# Please enter a valid number

# %%
try:
    d = {"name":"muskan","age":21}
    print(d[input("key Name: ").lower()])

except KeyError:
    print("Key Doesn't exists")
# Out:
# key Name:  NAme
# muskan

# %%
try:
    q = [10,20,30]
    idx = int(input('Index Number:'))
    print(q[idx])
  
except ValueError: 
    print('Please enter a valid value')

except IndexError:
    print('Index is out of bound')
# Out:
# Index Number: 1
# 20

# %%
try:
    file = open('test.txt',"r")
    file

except FileNotFoundError:
    print('> FIle Not Found <')

finally:
    print("*Program Finsihed*")
# Out:
# > FIle Not Found <
# *Program Finsihed*

# %%
i = {"id":1122, "lock":"INDEL"}
try:
    key = input("Enter Key :").lower()
    print(i[key])

except KeyError:
    print('Key Not Found')

except Exception:
    print("Something went wrong")
# Out:
# Enter Key : lock
# INDEL

# %%
try:
    file = open('test.txt',"r")
    num = 10/0

except FileNotFoundError:
    print('FIle Not Found')
except ZeroDivisionError:
    print('Cannot divide by 0')
# Out:
# FIle Not Found

# %%
while True:
    try:
        num = int(input("Enter a number"))
        print("You Entered : ",num)
        break
    except ValueError:
        print("Invalid Input ! Enter number only")
# Out:
# Enter a number ed
# Invalid Input ! Enter number only
# Enter a number 3'
# Invalid Input ! Enter number only
# Enter a number 3
# You Entered :  3

# %%
o = {"Name":"Muskan","Class":"X"}
while True:
    try:
        key = input("Enter a key:").capitalize()
        print(o[key])
        break
    except KeyError:
        print("Key Not Found ,Try Again")
# Out:
# Enter a key: muskan
# Key Not Found ,Try Again
# Enter a key: kjcd
# Key Not Found ,Try Again
# Enter a key: vcdv
# Key Not Found ,Try Again
# Enter a key: class
# X

# %%
total = 0
while True:
    value = input('Enter a number or exit to stop')
    if value.lower() == "stop":
        break
    try:
        total+=int(value)

    except ValueError:
        print("Invalid Input")

print("result: ",total)
# Out:
# Enter a number or exit to stop num
# Invalid Input
# Enter a number or exit to stop 2
# Enter a number or exit to stop 3
# Enter a number or exit to stop 4
# Enter a number or exit to stop 5
# Enter a number or exit to stop 6
# Enter a number or exit to stop stop
# result:  20
